# %%
import pandas as pd

# %%
data="https://www.w3schools.com/python/pandas/data.csv.txt"

# %%
df=pd.read_csv(data)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.drop("Duration", axis=1, inplace=True)

# %%
df
# Out:
#      Pulse  Maxpulse  Calories
# 0      110       130     409.1
# 1      117       145     479.0
# 2      103       135     340.0
# 3      109       175     282.4
# 4      117       148     406.0
# ..     ...       ...       ...
# 164    105       140     290.8
# 165    110       145     300.0
# 166    115       145     310.2
# 167    120       150     320.4
# 168    125       150     330.4
#
# [169 rows x 3 columns]

# %%
df.drop(0, inplace=True)

# %%
df
# Out:
#      Pulse  Maxpulse  Calories
# 1      117       145     479.0
# 2      103       135     340.0
# 3      109       175     282.4
# 4      117       148     406.0
# 5      102       127     300.0
# ..     ...       ...       ...
# 164    105       140     290.8
# 165    110       145     300.0
# 166    115       145     310.2
# 167    120       150     320.4
# 168    125       150     330.4
#
# [168 rows x 3 columns]

# %%
df.set_index("Pulse",inplace=True)

# %%
df
# Out:
#        Maxpulse  Calories
# Pulse
# 117         145     479.0
# 103         135     340.0
# 109         175     282.4
# 117         148     406.0
# 102         127     300.0
# ...         ...       ...
# 105         140     290.8
# 110         145     300.0
# 115         145     310.2
# 120         150     320.4
# 125         150     330.4
#
# [168 rows x 2 columns]

# %%
df.reset_index()
# Out:
#      Pulse  Maxpulse  Calories
# 0      117       145     479.0
# 1      103       135     340.0
# 2      109       175     282.4
# 3      117       148     406.0
# 4      102       127     300.0
# ..     ...       ...       ...
# 163    105       140     290.8
# 164    110       145     300.0
# 165    115       145     310.2
# 166    120       150     320.4
# 167    125       150     330.4
#
# [168 rows x 3 columns]

# %%
df1=pd.read_csv("data.csv")

# %%
df1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df1.dropna()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df1.fillna(130)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
g=df1.groupby("Duration")

# %%
g.sum()
# Out:
#           Pulse  Maxpulse  Calories
# Duration
# 15          204       239     174.7
# 20         1125      1314    1364.4
# 25          152       168     244.2
# 30         1757      2192    3074.0
# 45         3762      4663    9016.8
# 60         8384     10496   25815.3
# 75          245       300     650.8
# 80          123       146     643.1
# 90          750       931    4334.4
# 120         300       417    2000.5
# 150         406       521    3757.6
# 160         219       272    1887.4
# 180         281       377    2200.8
# 210         245       344    3236.4
# 270         100       131    1729.0
# 300         108       143    1500.2

# %%
g.mean().transpose()
# Out:
# Duration     15     20     25        30          45          60     75   \
# Pulse     102.00  125.0  152.0  109.8125  107.485714  106.126582  122.5
# Maxpulse  119.50  146.0  168.0  137.0000  133.228571  132.860759  150.0
# Calories   87.35  151.6  244.2  192.1250  273.236364  339.675000  325.4
#
# Duration    80       90          120     150    160         180     210  \
# Pulse     123.0   93.750  100.000000  101.50  109.5   93.666667   122.5
# Maxpulse  146.0  116.375  139.000000  130.25  136.0  125.666667   172.0
# Calories  643.1  541.800  666.833333  939.40  943.7  733.600000  1618.2
#
# Duration     270     300
# Pulse      100.0   108.0
# Maxpulse   131.0   143.0
# Calories  1729.0  1500.2

# %%
g.max().transpose()
# Out:
# Duration    15     20     25     30     45     60     75     80     90   \
# Pulse     124.0  153.0  152.0  159.0  149.0  136.0  125.0  123.0  100.0
# Maxpulse  139.0  172.0  168.0  182.0  175.0  170.0  150.0  146.0  127.0
# Calories  124.2  229.4  244.2  319.2  406.0  486.0  330.4  643.1  700.0
#
# Duration     120     150     160    180     210     270     300
# Pulse      100.0   107.0   110.0  101.0   137.0   100.0   108.0
# Maxpulse   157.0   135.0   137.0  130.0   184.0   131.0   143.0
# Calories  1000.1  1115.0  1034.4  800.4  1860.4  1729.0  1500.2

# %%
df1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
c1=df1[["Duration","Pulse"]][0:5]

# %%
c2=df1[["Duration","Pulse"]][5:10]

# %%
df2=pd.concat([c1, c2], axis=1)

# %%
df2.fillna("shiry")
# Out:
#   Duration  Pulse Duration  Pulse
# 0     60.0  110.0    shiry  shiry
# 1     60.0  117.0    shiry  shiry
# 2     60.0  103.0    shiry  shiry
# 3     45.0  109.0    shiry  shiry
# 4     45.0  117.0    shiry  shiry
# 5    shiry  shiry     60.0  102.0
# 6    shiry  shiry     60.0  110.0
# 7    shiry  shiry     45.0  104.0
# 8    shiry  shiry     30.0  109.0
# 9    shiry  shiry     60.0   98.0

# %%
k1=pd.DataFrame({"key1":[1,2,3],"key2":[4,5,6],"key3":[7,8,9]})

# %%
k2=pd.DataFrame({"key1":[1,22,3],"key4":[4,5,62],"key5":[27,8,9]})

# %%
k1
# Out:
#    key1  key2  key3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
k2
# Out:
#    key1  key4  key5
# 0     1     4    27
# 1    22     5     8
# 2     3    62     9

# %%
pd.merge(k1,k2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     7     4    27
# 1     3     6     9    62     9

# %%
pd.merge(k1, k2, how="left")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     7   4.0  27.0
# 1     2     5     8   NaN   NaN
# 2     3     6     9  62.0   9.0

# %%
pd.merge(k1, k2, how="right")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   7.0     4    27
# 1    22   NaN   NaN     5     8
# 2     3   6.0   9.0    62     9

# %%
pd.merge(k1, k2, how="inner")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     7     4    27
# 1     3     6     9    62     9

# %%
pd.merge(k1, k2, how="outer")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   7.0   4.0  27.0
# 1     2   5.0   8.0   NaN   NaN
# 2     3   6.0   9.0  62.0   9.0
# 3    22   NaN   NaN   5.0   8.0

# %%
df=df.reset_index()

# %%
df
# Out:
#      Pulse  Maxpulse  Calories
# 0      117       145     479.0
# 1      103       135     340.0
# 2      109       175     282.4
# 3      117       148     406.0
# 4      102       127     300.0
# ..     ...       ...       ...
# 163    105       140     290.8
# 164    110       145     300.0
# 165    115       145     310.2
# 166    120       150     320.4
# 167    125       150     330.4
#
# [168 rows x 3 columns]

# %%
ndf=pd.read_csv("data.csv")

# %%
ndf
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
ndf["sec"]=ndf["Duration"].apply(lambda x: x*60)

# %%
ndf
# Out:
#      Duration  Pulse  Maxpulse  Calories   sec
# 0          60    110       130     409.1  3600
# 1          60    117       145     479.0  3600
# 2          60    103       135     340.0  3600
# 3          45    109       175     282.4  2700
# 4          45    117       148     406.0  2700
# ..        ...    ...       ...       ...   ...
# 164        60    105       140     290.8  3600
# 165        60    110       145     300.0  3600
# 166        60    115       145     310.2  3600
# 167        75    120       150     320.4  4500
# 168        75    125       150     330.4  4500
#
# [169 rows x 5 columns]

# %%
df5=pd.DataFrame({"k1":[1,2,3,4],"k2":[4,5,6,7]}, index=["a","b","c","d"])

# %%
df5
# Out:
#    k1  k2
# a   1   4
# b   2   5
# c   3   6
# d   4   7

# %%
df5.set_index("k1", inplace=True)

# %%
df5.reset_index()
# Out:
#    k1  k2
# 0   1   4
# 1   2   5
# 2   3   6
# 3   4   7

# %%
df5=pd.DataFrame({"k1":[1,2,3,4],"k2":[4,5,6,7]}, index=["a","b","c","d"])

# %%
df5
# Out:
#    k1  k2
# a   1   4
# b   2   5
# c   3   6
# d   4   7

# %%
df5.reindex(["b","c","a","d"])
# Out:
#    k1  k2
# b   2   5
# c   3   6
# a   1   4
# d   4   7

# %%
df5.sort_values(["k1","k2"])
# Out:
#    k1  k2
# a   1   4
# b   2   5
# c   3   6
# d   4   7

# %%
df5.sort_index()
# Out:
#    k1  k2
# a   1   4
# b   2   5
# c   3   6
# d   4   7

# %%
df5.sort_index(ascending=False)
# Out:
#    k1  k2
# d   4   7
# c   3   6
# b   2   5
# a   1   4

# %%
df5["k1"].mean()
# Out:
# 2.5

# %%
df5["k1"].median()
# Out:
# 2.5

# %%
df5["k1"].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: k1, dtype: int64

# %%
df5["k1"].std()
# Out:
# 1.2909944487358056

# %%
df5["k1"].sum()
# Out:
# 10

# %%
pd.set_option("display.max_colwidth",1000)
df6=pd.DataFrame({"DataScience":["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical, and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science, data analytics, and big data industry including cloud infrastructure and real-time industry projects."]})

# %%
df6
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       DataScience
# ...

# %%
df6["len"]=df6["DataScience"].apply(len)

# %%
df6
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       DataScience  \
# ...

# %%
df6["words_len"]=df6["DataScience"].apply(lambda x: len(x.split()))

# %%
df6
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       DataScience  \
# ...

# %%
date=pd.date_range(start="2023/01/11",end="2023/05/21")

# %%
date
# Out:
# DatetimeIndex(['2023-01-11', '2023-01-12', '2023-01-13', '2023-01-14',
#                '2023-01-15', '2023-01-16', '2023-01-17', '2023-01-18',
#                '2023-01-19', '2023-01-20',
#                ...
#                '2023-05-12', '2023-05-13', '2023-05-14', '2023-05-15',
#                '2023-05-16', '2023-05-17', '2023-05-18', '2023-05-19',
#                '2023-05-20', '2023-05-21'],
#               dtype='datetime64[ns]', length=131, freq='D')

# %%
dt=pd.DataFrame(date,columns=["Date"])

# %%
dt
# Out:
#           Date
# 0   2023-01-11
# 1   2023-01-12
# 2   2023-01-13
# 3   2023-01-14
# 4   2023-01-15
# ..         ...
# 126 2023-05-17
# 127 2023-05-18
# 128 2023-05-19
# 129 2023-05-20
# 130 2023-05-21
#
# [131 rows x 1 columns]

# %%
dt.dtypes
# Out:
# Date    datetime64[ns]
# dtype: object

# %%
dt["update"]=pd.to_datetime(dt["Date"])

# %%
dt
# Out:
#           Date     update
# 0   2023-01-11 2023-01-11
# 1   2023-01-12 2023-01-12
# 2   2023-01-13 2023-01-13
# 3   2023-01-14 2023-01-14
# 4   2023-01-15 2023-01-15
# ..         ...        ...
# 126 2023-05-17 2023-05-17
# 127 2023-05-18 2023-05-18
# 128 2023-05-19 2023-05-19
# 129 2023-05-20 2023-05-20
# 130 2023-05-21 2023-05-21
#
# [131 rows x 2 columns]

# %%
dt.dtypes
# Out:
# Date      datetime64[ns]
# update    datetime64[ns]
# dtype: object

# %%
dt["year"]=dt["update"].dt.year

# %%
dt
# Out:
#           Date     update  year
# 0   2023-01-11 2023-01-11  2023
# 1   2023-01-12 2023-01-12  2023
# 2   2023-01-13 2023-01-13  2023
# 3   2023-01-14 2023-01-14  2023
# 4   2023-01-15 2023-01-15  2023
# ..         ...        ...   ...
# 126 2023-05-17 2023-05-17  2023
# 127 2023-05-18 2023-05-18  2023
# 128 2023-05-19 2023-05-19  2023
# 129 2023-05-20 2023-05-20  2023
# 130 2023-05-21 2023-05-21  2023
#
# [131 rows x 3 columns]

# %%
dt["month"]=dt["update"].dt.month

# %%
dt
# Out:
#           Date     update  year  month
# 0   2023-01-11 2023-01-11  2023      1
# 1   2023-01-12 2023-01-12  2023      1
# 2   2023-01-13 2023-01-13  2023      1
# 3   2023-01-14 2023-01-14  2023      1
# 4   2023-01-15 2023-01-15  2023      1
# ..         ...        ...   ...    ...
# 126 2023-05-17 2023-05-17  2023      5
# 127 2023-05-18 2023-05-18  2023      5
# 128 2023-05-19 2023-05-19  2023      5
# 129 2023-05-20 2023-05-20  2023      5
# 130 2023-05-21 2023-05-21  2023      5
#
# [131 rows x 4 columns]

# %%
dt["day"]=dt["update"].dt.day

# %%
dt
# Out:
#           Date     update  year  month  day
# 0   2023-01-11 2023-01-11  2023      1   11
# 1   2023-01-12 2023-01-12  2023      1   12
# 2   2023-01-13 2023-01-13  2023      1   13
# 3   2023-01-14 2023-01-14  2023      1   14
# 4   2023-01-15 2023-01-15  2023      1   15
# ..         ...        ...   ...    ...  ...
# 126 2023-05-17 2023-05-17  2023      5   17
# 127 2023-05-18 2023-05-18  2023      5   18
# 128 2023-05-19 2023-05-19  2023      5   19
# 129 2023-05-20 2023-05-20  2023      5   20
# 130 2023-05-21 2023-05-21  2023      5   21
#
# [131 rows x 5 columns]

# %%
pd.Timedelta(days=21, hours=16, minutes=20)
# Out:
# Timedelta('21 days 16:20:00')

# %%
data=["shiry", "kishy", "sandy", "shiry"]

# %%
cat=pd.Categorical(data)

# %%
cat.value_counts()
# Out:
# kishy    1
# sandy    1
# shiry    2
# dtype: int64

# %%
s=pd.Series([45,78,2,4,8])

# %%
s.plot()
# Out:
# <AxesSubplot: >

# %%
d=pd.DataFrame({"a":[1,2,5,6],"b":[7,8,4,7]})

# %%
d.plot(x="a", y="b")
# Out:
# <AxesSubplot: xlabel='a'>

# %%
d.plot.scatter(x="a", y="b")
# Out:
# <AxesSubplot: xlabel='a', ylabel='b'>
